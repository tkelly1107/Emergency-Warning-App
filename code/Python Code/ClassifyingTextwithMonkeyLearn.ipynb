# %%
# !pip install monkeylearn
# Out:
# ^C

# %%
import requests

# %%
from monkeylearn import MonkeyLearn

ml = MonkeyLearn('1e733b6a2d02ef8f16b73a4dcefe7d6beb5d38ff')
data = ["it could be set up with a little bit more user friendly interface and start with the current/ future radar instead of being on default past radar bit im happy with it"]
model_id = 'cl_7cSmAWxP'
result = ml.classifiers.classify(model_id, data)
print(result.body)
# Out:
# [{'text': 'it could be set up with a little bit more user friendly interface and start with the current/ future radar instead of being on default past radar bit im happy with it', 'external_id': None, 'error': False, 'classifications': [{'tag_name': 'Currency', 'tag_id': 124243233, 'confidence': 0.812}]}]

# %%
from monkeylearn import MonkeyLearn

ml = MonkeyLearn('1e733b6a2d02ef8f16b73a4dcefe7d6beb5d38ff')
data = ["Wish the collar radar was more active"]
model_id = 'cl_7cSmAWxP'
result = ml.classifiers.classify(model_id, data)
print(result.body)
# Out:
# [{'text': 'Wish the collar radar was more active', 'external_id': None, 'error': False, 'classifications': [{'tag_name': 'Functionality', 'tag_id': 124242478, 'confidence': 0.824}]}]

# %%
import json
f = open(r'C:\Users\recon\Desktop\review_collection_test.json')

# %%
import pandas as pd

# %%
df = pd.read_json(r'C:\Users\recon\Desktop\review_collection_test.json')

# %%
list = df['content'].astype(str).tolist()

# %%
list
# Out:
# ['Awesome',
#  'Fantastic, simple app.',
#  'Very very nice! Get it. Well worth it! 08.01.2020 still enjoying this app. Very well done. Get it! 04/2021...still enjoy it. 09/2021/ditto, 05/2022/ditto.',
#  'Love it this is a well set up program for viewing events.',
#  'Very useful information. Easy to access anytime anywhere',
#  'Good !',
#  'Awesome.',
#  '5 stars the first app I ever gave 5 stars too. Good job dev. This app is amazing 3D translucent earth made my earthquake this morning go from scary to cool. Thanks',
#  'Gives good graphics',
#  'Informative, good graphics!',
#  'Works good but slow on reports',
#  "This is the most accurate and up to date seismic app that I've ever used. I've personally used it for 7 years now and will continue to use it for the foreseeable future as well. Great app!",
#  'It takes an hr to show about a strong earthquake.',
#  'I like that it shows the precise area where a earthquake hit',
# ...
